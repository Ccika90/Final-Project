# %% [markdown]
# *****Import Libraries*****

# %%
#Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import pearsonr

# %% [markdown]
# ****Read the xlsx file****

# %%
#Step 2: Read the xlsx file
df = pd.read_excel("online_sales_dataset.xlsx")

# Display the DataFrame
df
# Out:
#        InvoiceNo StockCode   Description  Quantity         InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4         359178  SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...          ...       ...           ...       ...                 ...
# 49777     354083  SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778     296698  SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779     177622  SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780     701213  SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781     772215  SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %% [markdown]
# ****Understanding The Data****

# %%
#Step 3: Basic Information
print("\n--- Dataset Overview ---")
print("Shape of the dataset:", df.shape)
df.head()
# Out:
# --- Dataset Overview ---
# Shape of the dataset: (49782, 17)
#    InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 0     221958  SKU_1964   White Mug        38 2020-01-01 00:00:00       1.71
# 1     771155  SKU_1241   White Mug        18 2020-01-01 01:00:00      41.25
# 2     231932  SKU_1501  Headphones        49 2020-01-01 02:00:00      29.11
# 3     465838  SKU_1760   Desk Lamp        14 2020-01-01 03:00:00      76.68
# 4     359178  SKU_1386   USB Cable       -30 2020-01-01 04:00:00     -68.11
#
#    CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# 0     37039.0       Australia  0.470000  Bank Transfer         10.79
# 1     19144.0           Spain  0.190000        paypall          9.51
# 2     50472.0         Germany  0.350000  Bank Transfer         23.03
# 3     96586.0     Netherlands  0.140000        paypall         11.08
# 4         NaN  United Kingdom  1.501433  Bank Transfer           NaN
#
# ...

# %%
#Step 4: Check for missing values
print("\n--- Missing Values ---")
df.isnull().sum()
# Out:
# --- Missing Values ---
# InvoiceNo               0
# StockCode               0
# Description             0
# Quantity                0
# InvoiceDate             0
# UnitPrice               0
# CustomerID           4978
# Country                 0
# Discount                0
# PaymentMethod           0
# ShippingCost         2489
# Category                0
# SalesChannel            0
# ReturnStatus            0
# ShipmentProvider        0
# WarehouseLocation    3485
# OrderPriority           0
# dtype: int64

# %%
#Step 5: Summary statistics
print("\n--- Summary Statistics ---")
df.describe()
# Out:
# --- Summary Statistics ---
#            InvoiceNo      Quantity          InvoiceDate     UnitPrice  \
# count   49782.000000  49782.000000                49782  49782.000000
# mean   550681.239946     22.372343  2022-11-03 02:30:00     47.537862
# min    100005.000000    -50.000000  2020-01-01 00:00:00    -99.980000
# 25%    324543.000000     11.000000  2021-06-02 13:15:00     23.592500
# 50%    552244.000000     23.000000  2022-11-03 02:30:00     48.920000
# 75%    776364.000000     37.000000  2024-04-04 15:45:00     74.610000
# max    999997.000000     49.000000  2025-09-05 05:00:00    100.000000
# std    260703.009944     17.917774                  NaN     33.479510
#
#          CustomerID      Discount  ShippingCost
# count  44804.000000  49782.000000  47293.000000
# mean   55032.871775      0.275748     17.494529
# min    10001.000000      0.000000      5.000000
# 25%    32750.750000      0.130000     11.220000
# 50%    55165.000000      0.260000     17.500000
# ...

# %% [markdown]
# *****Data Wrangling and Cleaning*****

# %%
#Step 6: Convert column names to lowercase
df.columns = df.columns.str.lower()

# Display the updated DataFrame
df
# Out:
#        invoiceno stockcode   description  quantity         invoicedate  \
# 0         221958  SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1         771155  SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2         231932  SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3         465838  SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4         359178  SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...          ...       ...           ...       ...                 ...
# 49777     354083  SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778     296698  SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779     177622  SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780     701213  SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781     772215  SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unitprice  customerid         country  discount  paymentmethod  \
# ...

# %%
#Step 7: Mapping of old column names to new column names
column_mapping = {
        'invoiceno': 'invoice_no',
        'stockcode': 'stock_code',
        'description': 'description',
        'quantity': 'quantity',
        'invoicedate': 'invoice_date',
        'unitprice': 'unit_price',
        'customerid': 'customer_id',
        'country': 'country',
        'discount': 'discount',
        'paymentmethod': 'payment_method',
        'shippingcost': 'shipping_cost',
        'category': 'category',
        'saleschannel': 'sales_channel',
        'returnstatus': 'return_status',
        'shipmentprovider': 'shipment_provider',
        'warehouselocation': 'warehouse_location',
        'orderpriority': 'order_priority'
}

# Rename the columns
df.rename(columns=column_mapping, inplace=True)

# Display the updated DataFrame
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price  customer_id         country  discount payment_method  \
# ...

# %%
#Step 8: Convert customer_id from float to integer, skipping NA and inf values
df['customer_id'] = pd.to_numeric(df['customer_id'], errors='coerce').fillna(0).astype(int)

# Display the updated DataFrame
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price  customer_id         country  discount payment_method  \
# ...

# %%
# For IterativeImputer
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import LabelEncoder

# %%
# Encode customer_id if it's not numeric
if df['customer_id'].dtype == 'O' or df['customer_id'].dtype.name == 'category':
    le = LabelEncoder()
    # Fit only on non-null values
    non_null = df['customer_id'].dropna()
    le.fit(non_null)
    df['customer_id_encoded'] = df['customer_id'].map(lambda x: le.transform([x])[0] if pd.notnull(x) else np.nan)
else:
    df['customer_id_encoded'] = df['customer_id']

# %%
# Prepare data for imputation (add more features if you want to use them as predictors)
impute_features = ['customer_id_encoded']  # Add more columns if desired
imputer = IterativeImputer(random_state=0)
df[impute_features] = imputer.fit_transform(df[impute_features])

# If you encoded, decode back to original labels
if 'le' in locals():
    df['customer_id_imputed'] = df['customer_id_encoded'].round().astype(int)
    df['customer_id_imputed'] = le.inverse_transform(df['customer_id_imputed'])
else:
    df['customer_id_imputed'] = df['customer_id_encoded']

# Now df['customer_id_imputed'] contains the imputed values
print(df[['customer_id', 'customer_id_imputed']].head(10))
# Out:
#    customer_id  customer_id_imputed
# 0        37039              37039.0
# 1        19144              19144.0
# 2        50472              50472.0
# 3        96586              96586.0
# 4            0                  0.0
# 5        53887              53887.0
# 6        46567              46567.0
# 7        75098              75098.0
# 8        87950              87950.0
# 9        39718              39718.0

# %%
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price  customer_id         country  discount payment_method  \
# ...

# %%
#Step 10: Check for missing values in the customer_id column
missing_values = df['customer_id'].isnull()

# Display the boolean mask of missing values
print("Missing values in customer_id column:")
print(missing_values)

# Count the number of missing values
missing_count = missing_values.sum()
print(f'Number of missing values in customer_id column: {missing_count}')
# Out:
# Missing values in customer_id column:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49777    False
# 49778    False
# 49779    False
# 49780    False
# 49781    False
# Name: customer_id, Length: 49782, dtype: bool
# Number of missing values in customer_id column: 0

# %%
# Create a mapping from country to a warehouse_location that exists for that country
country_location_map = (
    df.dropna(subset=['warehouse_location'])  # Keep only rows where warehouse_location is not null
      .drop_duplicates(subset=['country', 'warehouse_location'])  # Unique pairs
      .groupby('country')['warehouse_location']
      .first()  # Take the first warehouse_location per country
      .to_dict()
)

# %%
# Function to fill missing warehouse_location based on country
def fill_location(row):
    if pd.isna(row['warehouse_location']):
        return country_location_map.get(row['country'], row['warehouse_location'])
    else:
        return row['warehouse_location']

# Apply the function to fill missing values
df['warehouse_location'] = df.apply(fill_location, axis=1)

# %%
#Step 13: Check for missing values in the warehouse_location column
missing_count = df['warehouse_location'].isnull().sum() + (df['warehouse_location'] == '').sum()

# Display the result
print(f'Number of missing values in the warehouse_location column: {missing_count}')
# Out:
# Number of missing values in the warehouse_location column: 0

# %%
#Drop unwanted columns
df.drop(columns=['customer_id_encoded', 'customer_id_imputed', 'customer_id'], inplace=True)

# %%
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price         country  discount payment_method  shipping_cost  \
# ...

# %%
#Step 14: Calculate the mean of the shipping_cost column, ignoring missing values
mean_shipping_cost = df['shipping_cost'].mean()

# Replace missing values with the mean
df['shipping_cost'] = df['shipping_cost'].fillna(mean_shipping_cost)

# Display the updated DataFrame
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price         country  discount payment_method  shipping_cost  \
# ...

# %%
# Convert invoice_date to datetime
df['invoice_date'] = pd.to_datetime(df['invoice_date'])

# %%
# Extracting time dimensions
df['year'] = df['invoice_date'].dt.year
df['month'] = df['invoice_date'].dt.month
df['quarter'] = df['invoice_date'].dt.quarter
df['day_of_week'] = df['invoice_date'].dt.day_name()
df['week'] = df['invoice_date'].dt.isocalendar().week

# %%
#Step 15: Check for missing values in the shipping_cost column
missing_count = df['shipping_cost'].isnull().sum() + (df['shipping_cost'] == '').sum()

# Display the result
print(f'Number of missing values in the shpping_cost column: {missing_count}')
df
# Out:
# Number of missing values in the shpping_cost column: 0
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
# ...

# %%
print("\n--- Missing Values ---")
print(df.isnull().sum())
# Out:
# --- Missing Values ---
# invoice_no            0
# stock_code            0
# description           0
# quantity              0
# invoice_date          0
# unit_price            0
# country               0
# discount              0
# payment_method        0
# shipping_cost         0
# category              0
# sales_channel         0
# return_status         0
# shipment_provider     0
# warehouse_location    0
# order_priority        0
# year                  0
# month                 0
# quarter               0
# day_of_week           0
# week                  0
# dtype: int64

# %%
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price         country  discount payment_method  shipping_cost  \
# ...

# %%
# Select numerical columns
num_cols = df.select_dtypes(include=[np.number]).columns
num_plots = len(num_cols)

# Determine number of rows and columns for subplots (e.g., 3 columns)
cols = 3
rows = (num_plots + cols - 1) // cols  # Ceiling division

fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 4))
axes = axes.flatten()  # Flatten in case of multiple rows

for i, col in enumerate(num_cols):
    ax = axes[i]
    df[col].hist(bins=30, ax=ax, color='skyblue', edgecolor='black')
    ax.set_title(f'Distribution of {col}', fontsize=12)
    ax.set_xlabel(col)
    ax.set_ylabel('Frequency')
    ax.grid(False)  # Optional: remove grid for cleaner look

# Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(pad=2.0)
plt.show()

# %%
# 8. Sales trends over time (if 'invoice_date' or similar exists)
if 'invoice_date' in df.columns:
    df['invoice_date'] = pd.to_datetime(df['invoice_date'])
    df['month'] = df['invoice_date'].dt.to_period('M')
    monthly_sales = df.groupby('month').apply(
        lambda x: (x['quantity'] * x['unit_price']).sum()
    )
    monthly_sales.plot(kind='line', marker='o')
    plt.title('Monthly Sales Trend')
    plt.xlabel('Month')
    plt.ylabel('Total Sales')
    plt.show()
# Out:
# C:\Users\umehc\AppData\Local\Temp\ipykernel_11180\1431543507.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   monthly_sales = df.groupby('month').apply(

# %%
 # 4. Product Analysis
if 'description' in df.columns:
    print("\n4. PRODUCT ANALYSIS")
    print("-"*50)
        
    # Top products by quantity sold
    top_products = df.groupby('description')['quantity'].sum().nlargest(10)
    plt.figure(figsize=(12, 6))
    top_products.plot(kind='bar')
    plt.title('Top 10 Products by Quantity Sold')
    plt.ylabel('Total Quantity Sold')
    plt.xticks(rotation=45)
    plt.show()
        
    # Price distribution
    plt.figure(figsize=(12, 6))
    sns.histplot(df['unit_price'], bins=50, kde=True)
    plt.title('Unit Price Distribution')
    plt.show()
# Out:
# 4. PRODUCT ANALYSIS
# --------------------------------------------------

# %%
# 5. Geographic Analysis
if 'country' in df.columns:
    print("\n5. GEOGRAPHIC ANALYSIS")
    print("-"*50)
        
    # Top countries by sales
    top_countries = df.groupby('country')['quantity'].sum().nlargest(10)
    plt.figure(figsize=(12, 6))
    top_countries.plot(kind='bar')
    plt.title('Top 10 Countries by Quantity Sold')
    plt.ylabel('Total Quantity Sold')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# 5. GEOGRAPHIC ANALYSIS
# --------------------------------------------------

# %%
# 6. Payment and Shipping Analysis
if 'payment_method' in df.columns and 'shipping_cost' in df.columns:
    print("\n6. PAYMENT & SHIPPING ANALYSIS")
    print("-"*50)
    plt.figure(figsize=(15, 5))
        
    plt.subplot(1, 2, 1)
    df['payment_method'].value_counts().plot(kind='bar')
    plt.title('Payment Method Distribution')
    plt.xticks(rotation=45)
        
    plt.subplot(1, 2, 2)
    sns.boxplot(x='payment_method', y='shipping_cost', data=df)
    plt.title('Shipping Cost by Payment Method')
    plt.xticks(rotation=45)
        
    plt.tight_layout()
    plt.show()
# Out:
# 6. PAYMENT & SHIPPING ANALYSIS
# --------------------------------------------------

# %%
# 7. Correlation Analysis
numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) > 1:
    print("\n7. CORRELATION ANALYSIS")
    print("-"*50)
    plt.figure(figsize=(10, 8))
    sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', center=0)
    plt.title('Correlation Matrix')
    plt.show()
# Out:
# 7. CORRELATION ANALYSIS
# --------------------------------------------------

# %%
# 13. Relationship between quantity and unit price
if 'quantity' in df.columns and 'unit_price' in df.columns:
    sns.scatterplot(x='quantity', y='unit_price', data=df)
    plt.title('Quantity vs. Unit Price')
    plt.show()

print("\nEDA Complete.")
# Out:
# EDA Complete.

# %% [markdown]
# *****Hypothesis Testing*****

# %%
df
# Out:
#        invoice_no stock_code   description  quantity        invoice_date  \
# 0          221958   SKU_1964     White Mug        38 2020-01-01 00:00:00
# 1          771155   SKU_1241     White Mug        18 2020-01-01 01:00:00
# 2          231932   SKU_1501    Headphones        49 2020-01-01 02:00:00
# 3          465838   SKU_1760     Desk Lamp        14 2020-01-01 03:00:00
# 4          359178   SKU_1386     USB Cable       -30 2020-01-01 04:00:00
# ...           ...        ...           ...       ...                 ...
# 49777      354083   SKU_1562      Blue Pen        25 2025-09-05 01:00:00
# 49778      296698   SKU_1930     USB Cable         7 2025-09-05 02:00:00
# 49779      177622   SKU_1766  Office Chair        43 2025-09-05 03:00:00
# 49780      701213   SKU_1602      Notebook        48 2025-09-05 04:00:00
# 49781      772215   SKU_1832     White Mug        30 2025-09-05 05:00:00
#
#        unit_price         country  discount payment_method  shipping_cost  \
# ...

# %% [markdown]
# *****Sales Channel and Revenue*****

# %% [markdown]
# ****Hypothesis 1: Sales through specific sales_channel generate higher revenue.****

# %%
def calculate_revenue(df):
    """
    Calculate revenue from the dataset with the given columns.
    Handles potential column name variations.
    
    Args:
        df (pd.DataFrame): Input dataframe with sales data
        
    Returns:
        pd.DataFrame: Original dataframe with added 'revenue' column
    """
    # Calculate revenue (unit_price * quantity - discount + shipping_cost)
    df['revenue'] = (df['unit_price'] * df['quantity']) - df['discount'].fillna(0)
    return df
    # Example usage
if __name__ == "__main__":
    # Load your dataset (replace with your actual data loading code)
    # df = pd.read_csv('your_dataset.csv')
    
    
    # Calculate revenue
    df = calculate_revenue(df)
    
    # Display results
    print("Dataset with Revenue Calculation Complete:")
# Out:
# Dataset with Revenue Calculation Complete:

# %%
# Group by sales_channel and calculate total revenue while keeping sales_channel as a column
channel_revenue = df.groupby('sales_channel', as_index=False)['revenue'].sum()

# Alternatively, you could use reset_index():
# channel_revenue = df.groupby('sales_channel')['revenue'].sum().reset_index()

# Display the results
print("\nTotal Revenue by Sales Channel:")
print("=" * 40)
print(channel_revenue)
# Out:
# Total Revenue by Sales Channel:
# ...
#   sales_channel       revenue
# 0      In-store  2.997508e+07
# 1        Online  3.015372e+07

# %%
# Step 4: Visualize the revenue by sales channel
plt.figure(figsize=(8, 6))
sns.barplot(x='sales_channel', y='revenue', data=channel_revenue, palette='Set2')
plt.title('Total Revenue by Sales Channel', fontsize=14)
plt.xlabel('Sales Channel', fontsize=12)
plt.ylabel('Total Revenue', fontsize=12)
plt.grid(True)
plt.show()
# Out:
# C:\Users\umehc\AppData\Local\Temp\ipykernel_11180\631910670.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sales_channel', y='revenue', data=channel_revenue, palette='Set2')

# %% [markdown]
# *****Testing the Hypothesis*****

# %%
import scipy.stats as stats
from itertools import combinations
def compare_sales_channels(df, channel1='Online', channel2='In-store'):
    """
    Compare revenue between two sales channels using t-test.
    
    Args:
        df (pd.DataFrame): DataFrame containing sales data
        channel1 (str): First sales channel to compare (default: 'Online')
        channel2 (str): Second sales channel to compare (default: 'In-store')
        
    Returns:
        dict: Dictionary containing test results and statistics
    """
    # Calculate revenue if not already present
    if 'revenue' not in df.columns:
        df['revenue'] = (df['unit_price'] * df['quantity']) - df['discount']
    
    # Filter data for the two channels
    channel1_data = df[df['sales_channel'].str.lower() == channel1.lower()]['revenue']
    channel2_data = df[df['sales_channel'].str.lower() == channel2.lower()]['revenue']
    
    # Check if we have enough data
    if len(channel1_data) < 2 or len(channel2_data) < 2:
        return {"error": f"Insufficient data ({channel1}: {len(channel1_data)}, {channel2}: {len(channel2_data)})"}
    
    # Perform Welch's t-test (doesn't assume equal variances)
    t_stat, p_value = stats.ttest_ind(channel1_data, channel2_data, equal_var=False)
    
    # Calculate means and std
    mean1, mean2 = channel1_data.mean(), channel2_data.mean()
    std1, std2 = channel1_data.std(), channel2_data.std()
    
    # Determine results
    alpha = 0.05
    significant = p_value < alpha
    higher_revenue = channel1 if mean1 > mean2 else channel2
    
    # Visualization
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='sales_channel', y='revenue', 
                data=df[df['sales_channel'].str.lower().isin([channel1.lower(), channel2.lower()])])
    plt.title(f'Revenue Comparison: {channel1} vs {channel2}')
    plt.xlabel('Sales Channel')
    plt.ylabel('Revenue')
    plt.show()
    
    return {
        "channels": [channel1, channel2],
        "t_statistic": t_stat,
        "p_value": p_value,
        "mean_revenues": {channel1: mean1, channel2: mean2},
        "std_revenues": {channel1: std1, channel2: std2},
        "sample_sizes": {channel1: len(channel1_data), channel2: len(channel2_data)},
        "significant_difference": significant,
        "higher_revenue": higher_revenue,
        "interpretation": (
            f"There {'IS' if significant else 'IS NOT'} a significant difference (p={p_value:.4f}). "
            f"{higher_revenue} generates higher revenue on average."
        )
    }

# Example usage
if __name__ == "__main__":
   
    
    # Compare Online vs In-store channels
    results = compare_sales_channels(df, 'Online', 'In-store')
    
    # Print results
    print("\nSales Channel Revenue Comparison (T-Test)")
    print("="*60)
    print(f"Channels Compared: {results['channels'][0]} vs {results['channels'][1]}")
    print(f"\nMean Revenue:")
    print(f"- {results['channels'][0]}: ${results['mean_revenues'][results['channels'][0]]:.2f}")
    print(f"- {results['channels'][1]}: ${results['mean_revenues'][results['channels'][1]]:.2f}")
    print(f"\nStandard Deviation:")
    print(f"- {results['channels'][0]}: ${results['std_revenues'][results['channels'][0]]:.2f}")
    print(f"- {results['channels'][1]}: ${results['std_revenues'][results['channels'][1]]:.2f}")
    print(f"\nSample Sizes:")
    print(f"- {results['channels'][0]}: {results['sample_sizes'][results['channels'][0]]}")
    print(f"- {results['channels'][1]}: {results['sample_sizes'][results['channels'][1]]}")
    print(f"\nT-statistic: {results['t_statistic']:.4f}")
    print(f"P-value: {results['p_value']:.4f}")
    print(f"\nConclusion: {results['interpretation']}")
# Out:
# Sales Channel Revenue Comparison (T-Test)
# ...
# Channels Compared: Online vs In-store
#
# Mean Revenue:
# - Online: $1203.69
# - In-store: $1212.04
#
# Standard Deviation:
# - Online: $1149.82
# - In-store: $1142.11
#
# Sample Sizes:
# - Online: 25051
# - In-store: 24731
#
# T-statistic: -0.8130
# P-value: 0.4162
#
# Conclusion: There IS NOT a significant difference (p=0.4162). In-store generates higher revenue on average.

# %% [markdown]
# *****Discounts and Quantity Purchased*****

# %% [markdown]
# ****Hypothesis 2: Higher discounts lead to an increase in the quantity of items purchased.****

# %%
def test_discount_quantity_hypothesis(df, discount_threshold=0.2):
    """
    Test whether higher discounts lead to increased quantity purchased using t-test.
    
    Args:
        df (pd.DataFrame): DataFrame containing sales data
        discount_threshold (float): Threshold to split into high/low discount groups
        
    Returns:
        dict: Dictionary containing test results and statistics
    """
    # Data preparation
    if 'discount' not in df.columns or 'quantity' not in df.columns:
        return {"error": "Required columns ('discount' or 'quantity') not found"}
    
    # Create discount groups
    df['discount_group'] = np.where(df['discount'] >= discount_threshold, 
                                  'High Discount', 
                                  'Low Discount')
    
    # Split into groups
    high_discount = df[df['discount_group'] == 'High Discount']['quantity']
    low_discount = df[df['discount_group'] == 'Low Discount']['quantity']
    
    # Check sample sizes
    if len(high_discount) < 2 or len(low_discount) < 2:
        return {"error": f"Insufficient data (High: {len(high_discount)}, Low: {len(low_discount)})"}
    
    # Perform Welch's t-test (doesn't assume equal variances)
    t_stat, p_value = stats.ttest_ind(high_discount, low_discount, equal_var=False)
    
    # Calculate statistics
    high_mean = high_discount.mean()
    low_mean = low_discount.mean()
    effect_size = (high_mean - low_mean) / np.sqrt(
        (high_discount.var() + low_discount.var()) / 2
    )
    
    # Visualization
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 2, 1)
    sns.boxplot(x='discount_group', y='quantity', data=df)
    plt.title('Quantity Purchased by Discount Group')
    
    plt.subplot(1, 2, 2)
    sns.scatterplot(x='discount', y='quantity', hue='discount_group', data=df)
    plt.axvline(x=discount_threshold, color='red', linestyle='--')
    plt.title('Discount vs Quantity Purchased')
    
    plt.tight_layout()
    plt.show()
    
    # Determine results
    alpha = 0.05
    significant = p_value < alpha
    supports_hypothesis = significant and (high_mean > low_mean)
    
    return {
        "discount_threshold": discount_threshold,
        "high_discount_mean": high_mean,
        "low_discount_mean": low_mean,
        "high_discount_count": len(high_discount),
        "low_discount_count": len(low_discount),
        "t_statistic": t_stat,
        "p_value": p_value,
        "effect_size": effect_size,
        "significant_difference": significant,
        "supports_hypothesis": supports_hypothesis,
        "interpretation": (
            f"The data {'supports' if supports_hypothesis else 'does not support'} "
            f"the hypothesis that higher discounts (≥{discount_threshold:.0%}) lead to "
            f"higher quantities purchased (p={p_value:.4f}, effect size={effect_size:.2f}). "
            f"High discount mean: {high_mean:.2f}, Low discount mean: {low_mean:.2f}"
        )
    }

# Example usage
if __name__ == "__main__":
   
    
    # Test the hypothesis with default 20% discount threshold
    results = test_discount_quantity_hypothesis(df)
    
    # Print results
    print("\nDiscount vs Quantity Purchased Hypothesis Test")
    print("="*70)
    print(f"Discount Threshold: ≥{results['discount_threshold']:.0%}")
    print(f"\nHigh Discount Group (≥{results['discount_threshold']:.0%}):")
    print(f"- Mean Quantity: {results['high_discount_mean']:.2f}")
    print(f"- Sample Size: {results['high_discount_count']}")
    print(f"\nLow Discount Group (<{results['discount_threshold']:.0%}):")
    print(f"- Mean Quantity: {results['low_discount_mean']:.2f}")
    print(f"- Sample Size: {results['low_discount_count']}")
    print(f"\nT-statistic: {results['t_statistic']:.4f}")
    print(f"P-value: {results['p_value']:.4f}")
    print(f"Effect Size (Cohen's d): {results['effect_size']:.2f}")
    print(f"\nConclusion: {results['interpretation']}")
# Out:
# Discount vs Quantity Purchased Hypothesis Test
# ...
# Discount Threshold: ≥20%
#
# High Discount Group (≥20%):
# - Mean Quantity: 21.73
# - Sample Size: 30861
#
# Low Discount Group (<20%):
# - Mean Quantity: 23.42
# - Sample Size: 18921
#
# T-statistic: -10.5617
# P-value: 0.0000
# Effect Size (Cohen's d): -0.10
#
# Conclusion: The data does not support the hypothesis that higher discounts (≥20%) lead to higher quantities purchased (p=0.0000, effect size=-0.10). High discount mean: 21.73, Low discount mean: 23.42

# %% [markdown]
# *****Country and Average Order Value*****

# %% [markdown]
# ****Hypothesis 3: Orders from certain countries have higher average order values.****

# %%
from itertools import combinations
def test_country_order_values(df, top_n=10):
    """
    Perform pairwise t-tests to compare average order values among top countries.
    
    Args:
        df (pd.DataFrame): DataFrame containing sales data
        top_n (int): Number of top countries to compare
        
    Returns:
        dict: Dictionary containing test results and statistics
    """
    # Calculate order value if not already present
    if 'order_value' not in df.columns:
        df['order_value'] = df['unit_price'] * df['quantity']
    
    # Check required columns
    if 'country' not in df.columns:
        return {"error": "Country column not found in dataset"}
    
    # Clean country data
    df['country'] = df['country'].str.strip().str.title()
    
    # Get top countries by order count
    top_countries = df['country'].value_counts().head(top_n).index.tolist()
    if len(top_countries) < 2:
        return {"error": "Insufficient countries for comparison"}
    
    # Prepare results storage
    results = {
        'country_comparisons': [],
        'top_countries': top_countries,
        'country_stats': {}
    }
    
    # Calculate statistics for each country
    for country in top_countries:
        country_data = df[df['country'] == country]['order_value']
        results['country_stats'][country] = {
            'mean': country_data.mean(),
            'std': country_data.std(),
            'count': len(country_data)
        }
    
    # Perform pairwise comparisons
    for country1, country2 in combinations(top_countries, 2):
        data1 = df[df['country'] == country1]['order_value']
        data2 = df[df['country'] == country2]['order_value']
        
        if len(data1) < 2 or len(data2) < 2:
            continue  # Skip if insufficient data
            
        # Welch's t-test
        t_stat, p_value = stats.ttest_ind(data1, data2, equal_var=False)
        
        # Calculate effect size
        pooled_std = np.sqrt((data1.std()**2 + data2.std()**2) / 2)
        effect_size = (data1.mean() - data2.mean()) / pooled_std
        
        # Determine significance
        significant = p_value < 0.05
        higher_value = country1 if data1.mean() > data2.mean() else country2
        
        results['country_comparisons'].append({
            'countries': [country1, country2],
            't_statistic': t_stat,
            'p_value': p_value,
            'effect_size': effect_size,
            'significant': significant,
            'higher_value': higher_value
        })
    
    # Visualization
    plt.figure(figsize=(15, 8))
    
    # Boxplot for top countries
    plt.subplot(1, 2, 1)
    sns.boxplot(x='country', y='order_value', 
                data=df[df['country'].isin(top_countries)])
    plt.title(f'Order Value Distribution for Top {top_n} Countries')
    plt.xlabel('Country')
    plt.ylabel('Order Value')
    plt.xticks(rotation=45)
    
    # Bar plot of average order values
    plt.subplot(1, 2, 2)
    avg_values = df[df['country'].isin(top_countries)].groupby('country')['order_value'].mean()
    avg_values.sort_values(ascending=False).plot(kind='bar')
    plt.title(f'Average Order Value for Top {top_n} Countries')
    plt.ylabel('Average Order Value')
    plt.xticks(rotation=45)
    
    plt.tight_layout()
    plt.show()
    
    return results

def print_results(results):
    """Print the analysis results in a readable format"""
    if "error" in results:
        print(f"Error: {results['error']}")
        return
    
    print("\nCOUNTRY ORDER VALUE ANALYSIS")
    print("="*70)
    
    # Print country statistics
    print("\nCOUNTRY STATISTICS:")
    stats_df = pd.DataFrame(results['country_stats']).T
    stats_df['mean'] = stats_df['mean'].apply(lambda x: f"${x:,.2f}")
    stats_df['std'] = stats_df['std'].apply(lambda x: f"${x:,.2f}")
    print(stats_df)
    
    # Print significant comparisons
    print("\nSIGNIFICANT DIFFERENCES (p < 0.05):")
    sig_comps = [c for c in results['country_comparisons'] if c['significant']]
    if not sig_comps:
        print("No significant differences found")
    else:
        for comp in sig_comps:
            print(f"\n{comp['countries'][0]} vs {comp['countries'][1]}:")
            print(f"  Higher Value: {comp['higher_value']}")
            print(f"  T-statistic: {comp['t_statistic']:.2f}")
            print(f"  P-value: {comp['p_value']:.4f}")
            print(f"  Effect Size: {comp['effect_size']:.2f}")

# Example usage
if __name__ == "__main__":
   
    
    # Run the analysis
    results = test_country_order_values(df, top_n=10)
    
    # Print results
    print_results(results)
# Out:
# COUNTRY ORDER VALUE ANALYSIS
# ...
#
# COUNTRY STATISTICS:
#                      mean        std   count
# France          $1,197.05  $1,126.16  4230.0
# Sweden          $1,194.22  $1,160.91  4211.0
# Germany         $1,222.22  $1,148.28  4182.0
# United Kingdom  $1,226.85  $1,152.32  4180.0
# Netherlands     $1,182.56  $1,117.96  4173.0
# Belgium         $1,228.79  $1,147.08  4170.0
# Portugal        $1,194.96  $1,153.70  4163.0
# Norway          $1,186.01  $1,138.97  4157.0
# Australia       $1,179.27  $1,143.66  4110.0
# Spain           $1,223.06  $1,149.64  4100.0
#
# SIGNIFICANT DIFFERENCES (p < 0.05):
#
# Belgium vs Australia:
#   Higher Value: Belgium
#   T-statistic: 1.97
#   P-value: 0.0492
#   Effect Size: 0.04

# %% [markdown]
# *****Category and Average Discount*****

# %% [markdown]
# ****Hypothesis 4: Certain product categories receive higher average discounts.****

# %%
# Step 1: Group by category and calculate the average discount
category_avg_discount = df.groupby('category')['discount'].mean().reset_index()
category_avg_discount.columns = ['category', 'average_discount']

# %%
# Step 2: Display the results
print("Average Discount by Category:")
print(category_avg_discount)
# Out:
# Average Discount by Category:
#       category  average_discount
# 0  Accessories          0.274611
# 1      Apparel          0.273157
# 2  Electronics          0.276590
# 3    Furniture          0.278429
# 4   Stationery          0.275897

# %%
from scipy.stats import ttest_ind
import itertools

# Assuming 'df' is your original DataFrame with 'category' and 'discount' columns
# Get unique categories
categories = df['category'].unique()

# Prepare a list to store results
results = []

# Perform pairwise t-tests between categories
for cat1, cat2 in itertools.combinations(categories, 2):
    # Extract discount data for each category
    discounts_cat1 = df[df['category'] == cat1]['discount']
    discounts_cat2 = df[df['category'] == cat2]['discount']
    
    # Perform two-sample t-test (Welch's t-test, does not assume equal variances)
    t_stat, p_value = ttest_ind(discounts_cat1, discounts_cat2, equal_var=False)
    
   
    #results['category_comparisons'].append({
            #'categories': [cat1, cat2],
            #'t_statistic': t_stat,
            #'p_value': p_value,
            #'effect_size': effect_size,
            #'significant': significant,
            #'higher_discount': higher_discount
        #})
    # Store the results
    results.append({
        'Category 1': cat1,
        'Category 2': cat2,
        'T-statistic': t_stat,
        'P-value': p_value,
       
    })

# Convert results to DataFrame for better readability
results_df = pd.DataFrame(results)

# Display the results
print(results_df)

# Optional: Interpret results at alpha = 0.05 significance level
alpha = 0.05
results_df['Significant Difference'] = results_df['P-value'] < alpha

print("\nInterpretation (Significant differences at alpha=0.05):")
print(results_df[['Category 1', 'Category 2', 'Significant Difference']])
# Out:
#     Category 1   Category 2  T-statistic   P-value
# 0      Apparel  Electronics    -1.049657  0.293889
# 1      Apparel  Accessories    -0.452134  0.651177
# 2      Apparel   Stationery    -0.872051  0.383191
# 3      Apparel    Furniture    -1.632626  0.102564
# 4  Electronics  Accessories     0.591844  0.553962
# 5  Electronics   Stationery     0.211656  0.832378
# 6  Electronics    Furniture    -0.547465  0.584065
# 7  Accessories   Stationery    -0.399636  0.689429
# 8  Accessories    Furniture    -1.155628  0.247847
# 9   Stationery    Furniture    -0.783044  0.433611
#
# Interpretation (Significant differences at alpha=0.05):
#     Category 1   Category 2  Significant Difference
# 0      Apparel  Electronics                   False
# 1      Apparel  Accessories                   False
# 2      Apparel   Stationery                   False
# 3      Apparel    Furniture                   False
# 4  Electronics  Accessories                   False
# ...

# %%
# Step 3: Visualize the average discount by category
plt.figure(figsize=(8, 6))
sns.barplot(x='category', y='average_discount', data=category_avg_discount, palette='Set2')
plt.title('Average Discount by Category', fontsize=14)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Average Discount (%)', fontsize=12)
plt.xticks(rotation=45)  # Rotate category names for better readability
plt.grid(True)
plt.show()
# Out:
# C:\Users\umehc\AppData\Local\Temp\ipykernel_11180\2445947933.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='category', y='average_discount', data=category_avg_discount, palette='Set2')
